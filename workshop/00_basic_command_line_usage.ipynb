# %%
# %pip install -e ..
# Out:
# Obtaining file:///Users/nikola/workspace/alparc
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for alparc (pyproject.toml) ... done
#   Created wheel for alparc: filename=alparc-0.0.1-0.editable-py3-none-any.whl size=2592 sha256=e3e506823cf4a5a4503e840d2dc8945c642d41590d385a937ccbdcd34a26986d
#   Stored in directory: /private/var/folders/n1/bxdrmv296493f6tbg9v8pjnh0000gn/T/pip-ephem-wheel-cache-0l1lmtvp/wheels/4e/8b/0b/d3bdb9934e92c8d0097403841e577be8baadd88948ad73ee72
# Successfully built alparc
# ...
#   Attempting uninstall: alparc
#     Found existing installation: alparc 0.0.1
#     Uninstalling alparc-0.0.1:
#       Successfully uninstalled alparc-0.0.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !alparc --help
# Out:
# usage: alparc [-h] {generate,diagnose}
#
# The ALPARC Toolbox: Artificial Languages with Phonological and Acoustic
# Rhythmicity Control
#
# ╭─ options ──────────────────────────────────────────────────────────────────╮
# │ -h, --help              show this help message and exit                    │
# ╰────────────────────────────────────────────────────────────────────────────╯
# ╭─ subcommands ──────────────────────────────────────────────────────────────╮
# │ {generate,diagnose}                                                        │
# │     generate            Generate a dataset of streams from a phenome       │
# │                         database and language-specific phoneme, syllable   │
# │                         and n-gram corpora                                 │
# │     diagnose            Diagnose a lexicon by checking its phonotactic,    │
# │                         acoustic and rhythmic properties                   │
# ...

# %%
# !alparc generate --help
# Out:
# usage: alparc generate [-h] [GENERATE OPTIONS]
#
# Generate a dataset of streams from a phenome database and language-specific
# phoneme, syllable and n-gram corpora
#
# ╭─ options ──────────────────────────────────────────────────────────────────╮
# │ -h, --help                                                                 │
# │     show this help message and exit                                        │
# ╰────────────────────────────────────────────────────────────────────────────╯
# ╭─ common options ───────────────────────────────────────────────────────────╮
# │ --common.lang {deu,eng}                                                    │
# │     The reference language to use (mainly for corpora) (default: deu)      │
# │ --common.log-dir STR|PATHLIKE                                              │
# │     The base directory to safe logs and results to (default: results)      │
# │ --common.name {None}|STR                                                   │
# ...

# %%
# !alparc generate
# Out:
# Generate Phonemes: ɡ|k|b|d|p|t|x|ç|ʃ|f|... (38 elements total)
# Generate Syllables: ɡaː|ɡeː|ɡiː|ɡoː|ɡuː|ɡyː|ɡøː|ɡɛː|kaː|keː|... (126 elements total)
# Generate Pseudo-Words: ...
# 100%|███████████████████████████████████| 10000/10000 [00:04<00:00, 2465.85it/s]
# Pseudo-Words: maːʃeːɡøː|kɛːriːvuː|nuːviːkɛː|siːmoːɡuː|voːraːɡɛː|ʃøːhoːbiː|beːniːçaː|zoːheːbøː|loːkaːfɛː|tøːfuːhiː|... (10000 elements total)
# Generate Lexicons: ...
# 100%|█████████████████████████████████████████████| 2/2 [00:05<00:00,  2.63s/it]
# Lexicons: ['çiːbɛːreː|loːfiːɡøː|føːtɛːhoː|suːhaːbiː', 'hyːfuːdiː|ɡøːsiːmɛː|piːlyːçaː|nuːkøːfiː']
# Generate Streams: ...
# 100%|█████████████████████████████████████████████| 2/2 [00:07<00:00,  3.58s/it]
# Streams:
# - çiː_hoː_fiː_reː_haː...hoː_suː_haː_loː_ɡøː
# - loː_fiː_ɡøː_çiː_bɛː...fiː_ɡøː_çiː_bɛː_reː
# - suː_tɛː_reː_çiː_bɛː...tɛː_biː_suː_fiː_hoː
# - fuː_piː_siː_ɡøː_çaː...ɡøː_fiː_piː_køː_çaː
# - ɡøː_siː_mɛː_nuː_køː...lyː_çaː_nuː_køː_fiː
# ...

# %%
# !alparc diagnose --lexicons "pi|ɾu|ta||ba|ɡo|li||to|ku|da||ɡu|haɪ|bo"
# Out:
# Read Lexicon: piɾuta|baɡoli|tokuda|ɡuhaɪbo
# Lexicon object saved to file: results/evaluate_lexicon_2025-05-20_14-32-39/_arpac/lexicon.json
# Lexicon summary saved to file: results/evaluate_lexicon_2025-05-20_14-32-39/lexicon.yml
# Generate Streams: ...
# 100%|█████████████████████████████████████████████| 2/2 [00:03<00:00,  1.80s/it]
# Streams:
# - pi_ku_to_ba_ɡu...ku_haɪ_ɾu_ta_ba
# - to_ku_da_pi_ɾu...ɡo_li_ɡu_haɪ_bo
# - ba_ku_li_to_haɪ...ɡo_da_to_ku_li
# - ɡo_ku_ɡu_li_da...ku_bo_ɾu_haɪ_ba
# - pi_ɾu_ta_to_ku...ɡo_li_to_ku_da
# - ba_haɪ_da_pi_ku...ku_bo_ba_ɡo_ta
