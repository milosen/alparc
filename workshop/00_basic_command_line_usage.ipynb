# %%
# %pip install alparc
# Out:
# ...
#   Obtaining dependency information for alparc from https://files.pythonhosted.org/packages/b4/db/a34d88b8a6a75e80f7ec55413a6722722c1aacbf91a0bfc22f6528c132a6/alparc-0.0.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for tyro from https://files.pythonhosted.org/packages/0f/d3/c73ba65f572fd6bafc319350bee76a306414595a3290ed3a8aec7d6c8cc3/tyro-0.9.20-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for docstring-parser>=0.15 from https://files.pythonhosted.org/packages/d5/7c/e9fcff7623954d86bdc17782036cbf715ecab1bec4847c008557affe1ca8/docstring_parser-0.16-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for shtab>=1.5.6 from https://files.pythonhosted.org/packages/74/03/3271b7bb470fbab4adf5bd30b0d32143909d96f3608d815b447357f47f2b/shtab-1.7.2-py3-none-any.whl.metadata
# ...

# %%
# !alparc --help
# Out:
# usage: alparc [-h] {generate,diagnose}
#
# The ALPARC Toolbox: Artificial Languages with Phonological and Acoustic
# Rhythmicity Control
#
# ╭─ options ──────────────────────────────────────────────────────────────────╮
# │ -h, --help              show this help message and exit                    │
# ╰────────────────────────────────────────────────────────────────────────────╯
# ╭─ subcommands ──────────────────────────────────────────────────────────────╮
# │ {generate,diagnose}                                                        │
# │     generate            Generate a dataset of streams from a phenome       │
# │                         database and language-specific phoneme, syllable   │
# │                         and n-gram corpora                                 │
# │     diagnose            Diagnose a lexicon by checking its phonotactic,    │
# │                         acoustic and rhythmic properties                   │
# ...

# %%
# !alparc generate --help
# Out:
# usage: alparc generate [-h] [GENERATE OPTIONS]
#
# Generate a dataset of streams from a phenome database and language-specific
# phoneme, syllable and n-gram corpora
#
# ╭─ options ──────────────────────────────────────────────────────────────────╮
# │ -h, --help                                                                 │
# │     show this help message and exit                                        │
# ╰────────────────────────────────────────────────────────────────────────────╯
# ╭─ common options ───────────────────────────────────────────────────────────╮
# │ --common.lang {deu,eng}                                                    │
# │     The reference language to use (mainly for corpora) (default: deu)      │
# │ --common.log-dir STR|PATHLIKE                                              │
# │     The base directory to safe logs and results to (default: results)      │
# │ --common.name {None}|STR                                                   │
# ...
